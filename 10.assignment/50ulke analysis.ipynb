# %%
import seaborn as sns
import pandas as pd

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize': [7, 7]}, font_scale=1.2)

# %%
df=pd.read_csv('50ulke.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.describe()
# Out:
#        Unnamed: 0  National Income     Growth    Per person
# count    50.00000        50.000000  50.000000     50.000000
# mean     24.50000      1646.348200   3.320400  27696.000000
# std      14.57738      3448.554429   2.053468  25094.131496
# min       0.00000       231.570000  -0.740000   1615.000000
# 25%      12.25000       353.440000   1.795000   6402.000000
# 50%      24.50000       522.985000   2.880000  14565.500000
# 75%      36.75000      1504.895000   4.287500  48738.250000
# max      49.00000     20412.870000   7.810000  86835.000000

# %%
df[df['Growth']<0]
# Out:
#     Unnamed: 0     Countries  National Income  Growth  Per person Continent
# 18          18  Saudi Arabia            748.0   -0.74      2265.0      Asia

# %% [markdown]
# يلاحظ ان معدل النمو في السعودية  بالسالب وهذا يعني وجود انخفاض علي عكس باقي الدول لديها زيادة في النمو

# %%
df[df['Per person']==86835]
# Out:
#     Unnamed: 0    Countries  National Income  Growth  Per person Continent
# 19          19  Switzerland           741.69    1.07     86835.0    Europe

# %% [markdown]
# اعلي دخل للمواطن في سويسرا علي الرغم من ان معدل نموها ليس كبير و وكمان الدخل القومي متوسط

# %%
df[df['Per person']==1615]
# Out:
#     Unnamed: 0 Countries  National Income  Growth  Per person Continent
# 40          40  Pakistan           324.73    5.28      1615.0      Asia

# %% [markdown]
# اقل دخل موجود في باكستان

# %%
sns.distplot(df['National Income'])

# %% [markdown]
# اغلب الدول دخلها القومي ما بين 1000 الي 3000
# #وفي اثنين
# #outliers (20000 ,15000)

# %%
sns.distplot(df['Growth'])

# %% [markdown]
# معظم الدول نموها ما بين 1.5 و 3
# كما يلاحظ وجود بعض الدول لديها نمو مرتفع عند 7

# %%
sns.distplot(df['Per person'])

# %% [markdown]
# معظم الدول دخل الفرد ما بين 1615 و24000

# %%
sns.countplot(x='Continent', data=df)

# %% [markdown]
# معظم الدول موجودة في اسيا واروبا

# %%
sns.violinplot(x="Continent", y="National Income", data=df)
sns.swarmplot(x="Continent", y="National Income", color="#474646", size=5, data=df);

# %% [markdown]
# كل الدول في افريقيا مستوي الدخل القومي متقارب ويكاد يكون متطابق

# %% [markdown]
# هي دوله واحدة oceania

# %% [markdown]
#  اما امريكيا الشمالية يوجد تفاوت كبير بين دخل القومي للدول
#  وكذلك في اسيا ولكن بتفاوت اقل

# %% [markdown]
# اما في اوربا و امريكيا الجنوبية يوجد تفاوت قليل بين الدول

# %%
sns.boxplot(x="Continent", y="National Income", data=df)

# %% [markdown]
# outlier

# %% [markdown]
# موجودة 3 في اسيا و 1 في اوربا و1 في امريكا الجنوبية

# %% [markdown]
# الدخل القومي في جميع القارات اقل من الدخل لدول امريكا الشمالية

# %%
sns.swarmplot(x="Continent", y="Growth", palette='rocket', size=5, data=df);

# %% [markdown]
# بيتاكد ان اغلب الدول نموها ما بين 1500 و 3000

# %%
sns.swarmplot(x="Continent", y="Per person", palette='rocket', size=5, data=df);

# %% [markdown]
# يوجد في اوربا دول دخل الفرد يصل الي80الف  واعلي من الخا سواء في اسيا وامريكيا الشمالية علي الرغم ان الدخل القومي في امريكيا الشمالية اعلي و في اسيا قريب من اوربا

# %%
sns.jointplot(x='Growth', y='National Income', data=df, kind='reg', height=8, color='m')

# %% [markdown]
# لا يوجد ترابط بين الدخل القومي و النمو

# %% [markdown]
# معظم الدول نموها ما بين 1.5 و8 ودخلها القومي ما بين 0 و2000

# %%
sns.jointplot(x='Growth', y='Per person', data=df, kind='reg', height=8, color='m')

# %% [markdown]
# يوجد علاقة عكسية بين دخل الفرد و النمو

# %%
sns.jointplot(x='National Income', y='Per person', data=df, kind='reg', height=8, color='m')

# %% [markdown]
# يوجد علاقة طردية  بين دخل الفرد و الدخل القومي

# %%
sns.jointplot(x='National Income', y='Per person', data=df, kind='kde', height=8, color='m')

# %% [markdown]
# يوجد تمركز ما بين 0 الي 1225 كدخل قومي ومن 0 ال10000كدخل للفرد
